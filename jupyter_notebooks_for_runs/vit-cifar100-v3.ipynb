# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import math
import copy
import random
import numpy as np
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
from einops import rearrange, repeat
from einops.layers.torch import Rearrange
import wandb
from PIL import Image
from torchvision.transforms import RandAugment

# %%
# Define MixUp Function
def mixup_data(x, y, alpha=0.2):
    '''Returns mixed inputs, pairs of targets, and lambda'''
    if alpha > 0:
        lam = np.random.beta(alpha, alpha)
    else:
        lam = 1
    batch_size = x.size()[0]
    index = torch.randperm(batch_size).to(x.device)

    mixed_x = lam * x + (1 - lam) * x[index, :]
    y_a, y_b = y, y[index]
    return mixed_x, y_a, y_b, lam

# Define CutMix Function
def cutmix_data(x, y, alpha=1.0):
    '''Returns cutmixed inputs, pairs of targets, and lambda'''
    if alpha > 0:
        lam = np.random.beta(alpha, alpha)
    else:
        lam = 1
    batch_size, C, H, W = x.size()
    index = torch.randperm(batch_size).to(x.device)

    # Bounding box coordinates
    cut_rat = np.sqrt(1. - lam)
    cut_w = np.int64(W * cut_rat)
    cut_h = np.int64(H * cut_rat)

    # Uniformly sample the center of the bbox
    cx = np.random.randint(W)
    cy = np.random.randint(H)

    bbx1 = np.clip(cx - cut_w // 2, 0, W)
    bby1 = np.clip(cy - cut_h // 2, 0, H)
    bbx2 = np.clip(cx + cut_w // 2, 0, W)
    bby2 = np.clip(cy + cut_h // 2, 0, H)

    # Apply CutMix
    x[:, :, bbx1:bbx2, bby1:bby2] = x[index, :, bbx1:bbx2, bby1:bby2]
    # Adjust lambda to exactly match pixel ratio
    lam = 1 - ((bbx2 - bbx1) * (bby2 - bby1) / (C * H * W))
    y_a, y_b = y, y[index]
    return x, y_a, y_b, lam

# Define MixUp and CutMix Criterion
def mixup_criterion(criterion, pred, y_a, y_b, lam):
    return lam * criterion(pred, y_a) + (1 - lam) * criterion(pred, y_b)

# %%
class Attention(nn.Module):
    def __init__(self, dim, *, dim_head=64, heads=8, dropout=0.0):
        super().__init__()
        inner_dim = dim_head * heads
        self.heads = heads
        self.dim_head = dim_head
        self.scale = dim_head ** -0.5

        self.to_qkv = nn.Linear(dim, inner_dim * 3, bias=False)
        self.attn_drop = nn.Dropout(dropout)
        self.proj = nn.Linear(inner_dim, dim)
        self.proj_drop = nn.Dropout(dropout)

    def forward(self, x):
        B, N, C = x.shape
        qkv = self.to_qkv(x)
        qkv = qkv.reshape(B, N, 3, self.heads, self.dim_head)
        qkv = qkv.permute(2, 0, 3, 1, 4)  # (3, B, heads, N, dim_head)
        q, k, v = qkv[0], qkv[1], qkv[2]
        q = q * self.scale
        attn = torch.matmul(q, k.transpose(-2, -1))
        attn = attn.softmax(dim=-1)
        attn = self.attn_drop(attn)
        out = torch.matmul(attn, v)
        out = out.transpose(1, 2).reshape(B, N, -1)
        out = self.proj(out)
        out = self.proj_drop(out)
        return out

class FeedForward(nn.Module):
    def __init__(self, dim, dim_inner, dropout=0.0):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(dim, dim_inner),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(dim_inner, dim),
            nn.Dropout(dropout)
        )

    def forward(self, x):
        return self.net(x)

# %%
def pair(t):
    return t if isinstance(t, tuple) else (t, t)

class StochasticDepth(nn.Module):
    def __init__(self, drop_prob):
        super().__init__()
        self.drop_prob = drop_prob

    def forward(self, x):
        if not self.training or self.drop_prob == 0.0:
            return x
        keep_prob = 1 - self.drop_prob
        # Shape [batch, 1, 1]
        mask = torch.rand(x.shape[0], 1, 1, device=x.device) < keep_prob
        return x / keep_prob * mask

class ConvStem(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(in_channels, out_channels // 2, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(out_channels // 2),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_channels // 2, out_channels, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        return self.conv(x)

# %%
class ViT(nn.Module):
    def __init__(
        self,
        *,
        image_size,
        patch_size,
        num_classes,
        dim,
        depth,
        heads,
        mlp_dim,
        dropout=0.2,          # Increased dropout
        emb_dropout=0.2,      # Increased emb_dropout
        channels=3,
        dim_head=64,
        stochastic_depth_rate=0.1  # Added stochastic depth rate
    ):
        super().__init__()
        self.conv_stem = ConvStem(channels, dim)
        image_height, image_width = pair(image_size)
        patch_height, patch_width = pair(patch_size)

        assert image_height % patch_height == 0 and image_width % patch_width == 0, \
            'Image dimensions must be divisible by the patch size.'

        num_patches = (image_height // patch_height) * (image_width // patch_width)
        # Updated patch_dim to use with convstem
        patch_dim = dim * patch_height * patch_width

        self.patch_size = patch_size
        self.dim = dim

        self.to_patch_embedding = nn.Sequential(
            Rearrange('b c (h ph) (w pw) -> b (h w) (ph pw c)', ph=patch_height, pw=patch_width),
            nn.Linear(patch_dim, dim)
        )

        self.cls_token = nn.Parameter(torch.randn(1, 1, dim))
        self.pos_embedding = nn.Parameter(torch.randn(1, num_patches + 1, dim))
        self.dropout = nn.Dropout(emb_dropout)

        # Transformer layers with Stochastic Depth
        self.transformer = nn.ModuleList([])
        for i in range(depth):
            sd_rate = stochastic_depth_rate * float(i) / depth  # Linearly increase drop rate
            self.transformer.append(nn.ModuleList([
                nn.LayerNorm(dim),
                Attention(dim, dim_head=dim_head, heads=heads, dropout=dropout),
                nn.Dropout(dropout),
                StochasticDepth(sd_rate),
                nn.LayerNorm(dim),
                FeedForward(dim, dim_inner=mlp_dim, dropout=dropout),
                nn.Dropout(dropout),
                StochasticDepth(sd_rate)
            ]))

        self.mlp_head = nn.Sequential(
            nn.LayerNorm(dim),
            nn.Linear(dim, num_classes)
        )

    def forward(self, img):
        x = self.conv_stem(img)
        x = self.to_patch_embedding(x)
        B, N, _ = x.shape

        cls_tokens = self.cls_token.expand(B, -1, -1)
        x = torch.cat((cls_tokens, x), dim=1)
        x = x + self.pos_embedding[:, :N + 1, :]
        x = self.dropout(x)

        for layer in self.transformer:
            norm1, attn, drop1, sd1, norm2, ff, drop2, sd2 = layer
            # Attention Block
            x_res = attn(norm1(x))
            x_res = drop1(x_res)
            x_res = sd1(x_res)
            x = x + x_res

            # FeedForward Block
            x_ff = ff(norm2(x))
            x_ff = drop2(x_ff)
            x_ff = sd2(x_ff)
            x = x + x_ff

        x = x[:, 0]
        x = self.mlp_head(x)
        return x

# %%
def main():
    # Set random seeds for reproducibility
    torch.manual_seed(42)
    torch.cuda.manual_seed_all(42)
    np.random.seed(42)
    random.seed(42)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

    # Initialize wandb
    wandb.init(project='vit-cifar100', config={
        'model': 'ViT',
        'dataset': 'CIFAR-100',
        'epochs': 200,
        'batch_size': 128,
        'learning_rate': 3e-4,
        'weight_decay': 0.01,
        'image_size': 32,
        'patch_size': 2,
        'dim': 768,
        'depth': 8,                  # Increased depth
        'heads': 8,
        'mlp_dim': 768 * 4,
        'dropout': 0.2,               # Increased dropout
        'emb_dropout': 0.2,           # Increased emb_dropout
        'num_classes': 100,
        'mixup_alpha': 0.2,
        'cutmix_alpha': 1.0,          # Added CutMix alpha
        'label_smoothing': 0.1,
        'stochastic_depth_rate': 0.1   # Added stochastic depth
    })
    config = wandb.config

    # Set device
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    # Data transforms for CIFAR-100 with additional augmentations
    transform_train = transforms.Compose([
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(),
        RandAugment(num_ops=2, magnitude=10),  # Added RandAugment
        transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
        transforms.RandomRotation(15),
        transforms.ToTensor(),
        transforms.Normalize((0.5071, 0.4867, 0.4408), (0.2675, 0.2565, 0.2761)),
    ])

    transform_test = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.5071, 0.4867, 0.4408), (0.2675, 0.2565, 0.2761)),
    ])

    # Load CIFAR-100 dataset
    train_dataset = datasets.CIFAR100(root='./data', train=True, download=True, transform=transform_train)
    test_dataset = datasets.CIFAR100(root='./data', train=False, download=True, transform=transform_test)

    train_loader = DataLoader(train_dataset, batch_size=config.batch_size, shuffle=True, num_workers=4, pin_memory=True)
    test_loader = DataLoader(test_dataset, batch_size=config.batch_size, shuffle=False, num_workers=4, pin_memory=True)

    # Initialize model
    model = ViT(
        image_size=config.image_size,
        patch_size=config.patch_size,
        num_classes=config.num_classes,
        dim=config.dim,
        depth=config.depth,
        heads=config.heads,
        mlp_dim=config.mlp_dim,
        dropout=config.dropout,
        emb_dropout=config.emb_dropout,
        channels=3,
        dim_head=64,
        stochastic_depth_rate=config.stochastic_depth_rate
    ).to(device)

    # Define Loss Function with Label Smoothing
    criterion = nn.CrossEntropyLoss(label_smoothing=config.label_smoothing)

    # Optimizer with parameter-wise weight decay (no decay for bias and norm parameters)
    no_decay = ['bias', 'LayerNorm.weight']
    optimizer_grouped_parameters = [
        {
            'params': [p for n, p in model.named_parameters() if not any(nd in n for nd in no_decay)],
            'weight_decay': config.weight_decay
        },
        {
            'params': [p for n, p in model.named_parameters() if any(nd in n for nd in no_decay)],
            'weight_decay': 0.0
        }
    ]
    optimizer = optim.AdamW(optimizer_grouped_parameters, lr=config.learning_rate)

    # Learning rate scheduler with OneCycleLR
    #scheduler = optim.lr_scheduler.OneCycleLR(
    #    optimizer,
    #    max_lr=config.learning_rate,
    #    steps_per_epoch=len(train_loader),
    #    epochs=config.epochs,
    #    pct_start=0.1,
    #    anneal_strategy='cos',
    #    cycle_momentum=True,
    #    base_momentum=0.85,
    #    max_momentum=0.95,
    #    div_factor=25.0,
    #    final_div_factor=1e4
    #)

    # Optimizer with parameter-wise weight decay (no decay for bias and norm parameters)
    no_decay = ['bias', 'LayerNorm.weight']
    optimizer_grouped_parameters = [
        {
            'params': [p for n, p in model.named_parameters() if not any(nd in n for nd in no_decay)],
            'weight_decay': config.weight_decay
        },
        {
            'params': [p for n, p in model.named_parameters() if any(nd in n for nd in no_decay)],
            'weight_decay': 0.0
        }
    ]
    optimizer = optim.AdamW(optimizer_grouped_parameters, lr=config.learning_rate)

    # Learning rate scheduler with cosine annealing and warmup
    total_steps = config.epochs * len(train_loader)
    warmup_steps = int(0.1 * total_steps)  # 10% of total steps for warmup

    def lr_lambda(current_step):
        if current_step < warmup_steps:
            return float(current_step) / float(max(1, warmup_steps))
        return 0.5 * (1. + math.cos(math.pi * (current_step - warmup_steps) / (total_steps - warmup_steps)))

    scheduler = optim.lr_scheduler.LambdaLR(optimizer, lr_lambda)


    # Training loop with Early Stopping
    best_acc = 0.0
    best_model_wts = copy.deepcopy(model.state_dict())
    patience = 30  # Increased patience for more epochs
    trigger_times = 0

    for epoch in range(config.epochs):
        model.train()
        running_loss = 0.0
        correct = 0
        total = 0

        for batch_idx, (inputs, targets) in enumerate(train_loader):
            inputs, targets = inputs.to(device), targets.to(device)

            # Decide whether to apply MixUp or CutMix
            r = np.random.rand(1)
            if r < 0.5:
                # Apply MixUp
                inputs, targets_a, targets_b, lam = mixup_data(inputs, targets, alpha=config.mixup_alpha)
                outputs = model(inputs)  # Store outputs
                loss = mixup_criterion(criterion, outputs, targets_a, targets_b, lam)
            else:
                # Apply CutMix
                inputs, targets_a, targets_b, lam = cutmix_data(inputs, targets, alpha=config.cutmix_alpha)
                outputs = model(inputs)  # Store outputs
                loss = mixup_criterion(criterion, outputs, targets_a, targets_b, lam)

            optimizer.zero_grad()
            loss.backward()

            # Gradient clipping
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)

            optimizer.step()
            scheduler.step()

            running_loss += loss.item()

            # Calculate accuracy
            _, predicted = outputs.max(1)
            total += targets.size(0)
            if r < 0.5:
                # MixUp accuracy approximation
                correct += (lam * predicted.eq(targets_a).sum().item() + (1 - lam) * predicted.eq(targets_b).sum().item())
            else:
                # CutMix accuracy approximation
                correct += (lam * predicted.eq(targets_a).sum().item() + (1 - lam) * predicted.eq(targets_b).sum().item())

            if batch_idx % 100 == 0:
                wandb.log({
                    'train_loss': running_loss / (batch_idx + 1),
                    'train_acc': 100. * correct / total,
                    'learning_rate': scheduler.get_last_lr()[0]
                })

        train_loss = running_loss / len(train_loader)
        train_acc = 100. * correct / total

        # Validation Phase
        model.eval()
        test_loss = 0.0
        correct = 0
        total = 0
        with torch.no_grad():
            for inputs, targets in test_loader:
                inputs, targets = inputs.to(device), targets.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, targets)

                test_loss += loss.item()
                _, predicted = outputs.max(1)
                total += targets.size(0)
                correct += predicted.eq(targets).sum().item()

        acc = 100. * correct / total
        avg_test_loss = test_loss / len(test_loader)
        wandb.log({
            'test_loss': avg_test_loss,
            'test_acc': acc,
            'epoch': epoch
        })

        # Early Stopping Check
        if acc > best_acc:
            best_acc = acc
            best_model_wts = copy.deepcopy(model.state_dict())
            trigger_times = 0
            # Save the best model
            torch.save(model.state_dict(), 'best_cifar100_vit.pth')
        else:
            trigger_times += 1
            if trigger_times >= patience:
                print("Early stopping triggered!")
                break

        print(f"Epoch {epoch + 1}/{config.epochs} - "
              f"Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.2f}%, "
              f"Test Loss: {avg_test_loss:.4f}, Test Acc: {acc:.2f}%")

        # Log additional hyperparameters and metrics at the end of each epoch
        wandb.log({
            'epoch': epoch,
            'best_test_acc': best_acc
        })

    # Load best model weights
    model.load_state_dict(best_model_wts)
    print(f"Training completed. Best Test Accuracy: {best_acc:.2f}%")
    wandb.finish()

if __name__ == '__main__':
    main()
# Out:
# Finishing last run (ID:p8s97fgn) before initializing another...
#     <style>
#         .wandb-row {
#             display: flex;
#             flex-direction: row;
#             flex-wrap: wrap;
#             justify-content: flex-start;
#             width: 100%;
#         }
#         .wandb-col {
#             display: flex;
#             flex-direction: column;
#             flex-basis: 100%;
#             flex: 1;
#             padding: 10px;
#         }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>best_test_acc</td><td>▁▂▃▄▅▅▆▇▇████████████</td></tr><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>learning_rate</td><td>▁▁▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▆▆▇▇▇███</td></tr><tr><td>test_acc</td><td>▁▂▃▄▅▅▆▇▇█████▇▇▇▇▆▇▇</td></tr><tr><td>test_loss</td><td>█▇▅▄▄▃▂▂▁▁▁▁▁▁▁▁▁▂▂▂▂</td></tr><tr><td>train_acc</td><td>▁▁▁▁▃▂▂▃▃▃▃▂▃▄▄▅▆▆▅▅▆█▆▆▆▃▆▆▆▆▆▅▅▆▆▅▆▆▅▅</td></tr><tr><td>train_loss</td><td>█▇▆▄▄▄▄▄▃▃▂▂▂▁▂▂▃▂▂▂▂▂▁▁▁▂▁▂▂▂▂▂▂▂▂▂▂▃▂▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_test_acc</td><td>30.02</td></tr><tr><td>epoch</td><td>20</td></tr><tr><td>learning_rate</td><td>0.0005</td></tr><tr><td>test_acc</td><td>25.15</td></tr><tr><td>test_loss</td><td>3.32945</td></tr><tr><td>train_acc</td><td>13.06596</td></tr><tr><td>train_loss</td><td>3.98994</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">eager-dawn-21</strong> at: <a href='https://wandb.ai/pratkumar-stony-brook-university/vit-cifar100/runs/p8s97fgn' target="_blank">https://wandb.ai/pratkumar-stony-brook-university/vit-cifar100/runs/p8s97fgn</a><br/> View project at: <a href='https://wandb.ai/pratkumar-stony-brook-university/vit-cifar100' target="_blank">https://wandb.ai/pratkumar-stony-brook-university/vit-cifar100</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20241202_014841-p8s97fgn/logs</code>
# Successfully finished last run (ID:p8s97fgn). Initializing new run:<br/>
# Tracking run with wandb version 0.18.7
# Run data is saved locally in <code>/content/wandb/run-20241202_022253-vsr9zt83</code>
# Syncing run <strong><a href='https://wandb.ai/pratkumar-stony-brook-university/vit-cifar100/runs/vsr9zt83' target="_blank">pleasant-surf-22</a></strong> to <a href='https://wandb.ai/pratkumar-stony-brook-university/vit-cifar100' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/pratkumar-stony-brook-university/vit-cifar100' target="_blank">https://wandb.ai/pratkumar-stony-brook-university/vit-cifar100</a>
#  View run at <a href='https://wandb.ai/pratkumar-stony-brook-university/vit-cifar100/runs/vsr9zt83' target="_blank">https://wandb.ai/pratkumar-stony-brook-university/vit-cifar100/runs/vsr9zt83</a>
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch 1/200 - Train Loss: 4.6408, Train Acc: 1.52%, Test Loss: 4.3702, Test Acc: 3.37%
# Epoch 2/200 - Train Loss: 4.4767, Train Acc: 3.19%, Test Loss: 4.2319, Test Acc: 6.03%
# Epoch 3/200 - Train Loss: 4.3574, Train Acc: 4.96%, Test Loss: 3.9533, Test Acc: 11.14%
# Epoch 4/200 - Train Loss: 4.2809, Train Acc: 6.55%, Test Loss: 3.8191, Test Acc: 13.86%
# Epoch 5/200 - Train Loss: 4.2154, Train Acc: 8.23%, Test Loss: 3.6639, Test Acc: 17.28%
# Epoch 6/200 - Train Loss: 4.1606, Train Acc: 9.25%, Test Loss: 3.6180, Test Acc: 17.94%
# Epoch 7/200 - Train Loss: 4.0677, Train Acc: 11.01%, Test Loss: 3.4404, Test Acc: 23.42%
# Epoch 8/200 - Train Loss: 4.0113, Train Acc: 12.24%, Test Loss: 3.3382, Test Acc: 25.06%
# Epoch 9/200 - Train Loss: 3.9895, Train Acc: 12.98%, Test Loss: 3.2585, Test Acc: 26.68%
# Epoch 10/200 - Train Loss: 3.9873, Train Acc: 13.20%, Test Loss: 3.1957, Test Acc: 28.68%
# Epoch 11/200 - Train Loss: 3.9209, Train Acc: 14.39%, Test Loss: 3.1629, Test Acc: 29.64%
# Epoch 12/200 - Train Loss: 3.9138, Train Acc: 14.87%, Test Loss: 3.2370, Test Acc: 27.99%
# Epoch 13/200 - Train Loss: 3.8697, Train Acc: 15.77%, Test Loss: 3.0928, Test Acc: 31.00%
# Epoch 14/200 - Train Loss: 3.8681, Train Acc: 15.78%, Test Loss: 3.0546, Test Acc: 32.36%
# Epoch 15/200 - Train Loss: 3.8465, Train Acc: 16.32%, Test Loss: 3.0090, Test Acc: 33.37%
# Epoch 16/200 - Train Loss: 3.8143, Train Acc: 16.74%, Test Loss: 3.0000, Test Acc: 33.42%
# Epoch 17/200 - Train Loss: 3.8322, Train Acc: 16.83%, Test Loss: 2.9727, Test Acc: 33.90%
# Epoch 18/200 - Train Loss: 3.7633, Train Acc: 18.21%, Test Loss: 2.9507, Test Acc: 34.96%
# Epoch 19/200 - Train Loss: 3.8018, Train Acc: 17.62%, Test Loss: 2.9193, Test Acc: 34.86%
# Epoch 20/200 - Train Loss: 3.7492, Train Acc: 18.64%, Test Loss: 2.8903, Test Acc: 36.56%
# Epoch 21/200 - Train Loss: 3.6792, Train Acc: 19.69%, Test Loss: 2.8444, Test Acc: 36.90%
# Epoch 22/200 - Train Loss: 3.6948, Train Acc: 19.80%, Test Loss: 2.8084, Test Acc: 38.23%
# Epoch 23/200 - Train Loss: 3.6702, Train Acc: 20.25%, Test Loss: 2.8244, Test Acc: 38.07%
# Epoch 24/200 - Train Loss: 3.7176, Train Acc: 19.48%, Test Loss: 2.7567, Test Acc: 39.67%
# Epoch 25/200 - Train Loss: 3.6314, Train Acc: 21.33%, Test Loss: 2.7690, Test Acc: 39.24%
# Epoch 26/200 - Train Loss: 3.6330, Train Acc: 21.24%, Test Loss: 2.7494, Test Acc: 39.20%
# Epoch 27/200 - Train Loss: 3.6228, Train Acc: 21.57%, Test Loss: 2.7243, Test Acc: 41.03%
# Epoch 28/200 - Train Loss: 3.6289, Train Acc: 21.62%, Test Loss: 2.6941, Test Acc: 41.13%
# Epoch 29/200 - Train Loss: 3.5701, Train Acc: 22.74%, Test Loss: 2.7087, Test Acc: 41.43%
# Epoch 30/200 - Train Loss: 3.5668, Train Acc: 22.98%, Test Loss: 2.6821, Test Acc: 41.66%
# Epoch 31/200 - Train Loss: 3.5577, Train Acc: 23.03%, Test Loss: 2.6199, Test Acc: 43.44%
# Epoch 32/200 - Train Loss: 3.5276, Train Acc: 23.66%, Test Loss: 2.6514, Test Acc: 42.62%
# Epoch 33/200 - Train Loss: 3.4938, Train Acc: 24.51%, Test Loss: 2.5787, Test Acc: 44.20%
# Epoch 34/200 - Train Loss: 3.4887, Train Acc: 24.72%, Test Loss: 2.6610, Test Acc: 41.97%
# Epoch 35/200 - Train Loss: 3.5238, Train Acc: 23.89%, Test Loss: 2.6096, Test Acc: 43.91%
# Epoch 36/200 - Train Loss: 3.4638, Train Acc: 25.34%, Test Loss: 2.5624, Test Acc: 44.84%
# Epoch 37/200 - Train Loss: 3.4638, Train Acc: 25.54%, Test Loss: 2.5301, Test Acc: 45.50%
# Epoch 38/200 - Train Loss: 3.4396, Train Acc: 25.89%, Test Loss: 2.5322, Test Acc: 45.44%
# Epoch 39/200 - Train Loss: 3.4429, Train Acc: 25.91%, Test Loss: 2.5002, Test Acc: 46.47%
# Epoch 40/200 - Train Loss: 3.4038, Train Acc: 26.94%, Test Loss: 2.4728, Test Acc: 47.28%
# Epoch 41/200 - Train Loss: 3.4112, Train Acc: 26.86%, Test Loss: 2.4994, Test Acc: 46.40%
# Epoch 42/200 - Train Loss: 3.3435, Train Acc: 28.22%, Test Loss: 2.4340, Test Acc: 48.43%
# Epoch 43/200 - Train Loss: 3.3845, Train Acc: 27.41%, Test Loss: 2.4471, Test Acc: 48.41%
# Epoch 44/200 - Train Loss: 3.3819, Train Acc: 27.55%, Test Loss: 2.4426, Test Acc: 48.07%
# Epoch 45/200 - Train Loss: 3.3820, Train Acc: 27.61%, Test Loss: 2.4416, Test Acc: 48.84%
# Epoch 46/200 - Train Loss: 3.3373, Train Acc: 28.72%, Test Loss: 2.4302, Test Acc: 49.05%
# Epoch 47/200 - Train Loss: 3.3170, Train Acc: 28.79%, Test Loss: 2.4069, Test Acc: 48.98%
# Epoch 48/200 - Train Loss: 3.3269, Train Acc: 28.93%, Test Loss: 2.3930, Test Acc: 49.98%
# Epoch 49/200 - Train Loss: 3.2690, Train Acc: 30.24%, Test Loss: 2.3816, Test Acc: 50.44%
# Epoch 50/200 - Train Loss: 3.3053, Train Acc: 29.57%, Test Loss: 2.3683, Test Acc: 50.82%
# Epoch 51/200 - Train Loss: 3.2708, Train Acc: 30.48%, Test Loss: 2.4035, Test Acc: 49.48%
# Epoch 52/200 - Train Loss: 3.2486, Train Acc: 30.96%, Test Loss: 2.3499, Test Acc: 51.04%
# Epoch 53/200 - Train Loss: 3.2702, Train Acc: 30.48%, Test Loss: 2.2697, Test Acc: 53.00%
# Epoch 54/200 - Train Loss: 3.2464, Train Acc: 31.22%, Test Loss: 2.3925, Test Acc: 49.86%
# Epoch 55/200 - Train Loss: 3.2016, Train Acc: 32.15%, Test Loss: 2.3016, Test Acc: 52.15%
# Epoch 56/200 - Train Loss: 3.2038, Train Acc: 32.05%, Test Loss: 2.2857, Test Acc: 52.97%
# Epoch 57/200 - Train Loss: 3.1897, Train Acc: 32.50%, Test Loss: 2.2962, Test Acc: 52.91%
# Epoch 58/200 - Train Loss: 3.2002, Train Acc: 32.01%, Test Loss: 2.2660, Test Acc: 53.71%
# Epoch 59/200 - Train Loss: 3.1996, Train Acc: 32.39%, Test Loss: 2.2760, Test Acc: 52.69%
# Epoch 60/200 - Train Loss: 3.1692, Train Acc: 33.09%, Test Loss: 2.3044, Test Acc: 52.50%
# Epoch 61/200 - Train Loss: 3.1587, Train Acc: 33.19%, Test Loss: 2.2674, Test Acc: 53.67%
# Epoch 62/200 - Train Loss: 3.1284, Train Acc: 34.40%, Test Loss: 2.2249, Test Acc: 54.91%
# Epoch 63/200 - Train Loss: 3.1334, Train Acc: 34.39%, Test Loss: 2.2149, Test Acc: 55.09%
# Epoch 64/200 - Train Loss: 3.0088, Train Acc: 36.64%, Test Loss: 2.2237, Test Acc: 55.80%
# Epoch 65/200 - Train Loss: 3.1325, Train Acc: 34.21%, Test Loss: 2.2120, Test Acc: 55.06%
# Epoch 66/200 - Train Loss: 3.0909, Train Acc: 35.19%, Test Loss: 2.1853, Test Acc: 56.28%
# Epoch 67/200 - Train Loss: 3.0789, Train Acc: 35.62%, Test Loss: 2.1829, Test Acc: 56.17%
# Epoch 68/200 - Train Loss: 3.0428, Train Acc: 36.45%, Test Loss: 2.1706, Test Acc: 56.36%
# Epoch 69/200 - Train Loss: 3.1115, Train Acc: 34.84%, Test Loss: 2.1923, Test Acc: 56.04%
# Epoch 70/200 - Train Loss: 3.0452, Train Acc: 36.49%, Test Loss: 2.1734, Test Acc: 56.34%
# Epoch 71/200 - Train Loss: 2.9561, Train Acc: 38.36%, Test Loss: 2.1800, Test Acc: 56.11%
# Epoch 72/200 - Train Loss: 2.9515, Train Acc: 38.72%, Test Loss: 2.1141, Test Acc: 58.31%
# Epoch 73/200 - Train Loss: 2.9087, Train Acc: 39.44%, Test Loss: 2.1127, Test Acc: 58.53%
# Epoch 74/200 - Train Loss: 3.0014, Train Acc: 37.43%, Test Loss: 2.1334, Test Acc: 58.08%
# Epoch 75/200 - Train Loss: 3.0452, Train Acc: 36.73%, Test Loss: 2.1896, Test Acc: 55.98%
# Epoch 76/200 - Train Loss: 2.9618, Train Acc: 38.57%, Test Loss: 2.1512, Test Acc: 57.21%
# Epoch 77/200 - Train Loss: 2.9645, Train Acc: 38.63%, Test Loss: 2.1393, Test Acc: 57.86%
# Epoch 78/200 - Train Loss: 2.8882, Train Acc: 40.34%, Test Loss: 2.1174, Test Acc: 58.21%
# Epoch 79/200 - Train Loss: 2.9237, Train Acc: 39.71%, Test Loss: 2.1095, Test Acc: 59.12%
# Epoch 80/200 - Train Loss: 2.8376, Train Acc: 41.60%, Test Loss: 2.0790, Test Acc: 59.35%
# Epoch 81/200 - Train Loss: 2.9050, Train Acc: 40.28%, Test Loss: 2.1175, Test Acc: 58.96%
# Epoch 82/200 - Train Loss: 2.8708, Train Acc: 41.18%, Test Loss: 2.1009, Test Acc: 58.83%
# Epoch 83/200 - Train Loss: 2.7908, Train Acc: 42.76%, Test Loss: 2.0875, Test Acc: 59.23%
# Epoch 84/200 - Train Loss: 2.9366, Train Acc: 39.55%, Test Loss: 2.0918, Test Acc: 59.37%
# Epoch 85/200 - Train Loss: 2.8689, Train Acc: 41.25%, Test Loss: 2.0785, Test Acc: 59.87%
# Epoch 86/200 - Train Loss: 2.8725, Train Acc: 41.21%, Test Loss: 2.0723, Test Acc: 59.72%
# Epoch 87/200 - Train Loss: 2.8622, Train Acc: 41.77%, Test Loss: 2.0456, Test Acc: 60.42%
# Epoch 88/200 - Train Loss: 2.8196, Train Acc: 42.46%, Test Loss: 2.0852, Test Acc: 59.81%
# Epoch 89/200 - Train Loss: 2.8111, Train Acc: 42.70%, Test Loss: 2.0533, Test Acc: 60.95%
# Epoch 90/200 - Train Loss: 2.8999, Train Acc: 40.97%, Test Loss: 2.0898, Test Acc: 59.09%
# Epoch 91/200 - Train Loss: 2.8071, Train Acc: 43.16%, Test Loss: 2.0967, Test Acc: 59.36%
# Epoch 92/200 - Train Loss: 2.8189, Train Acc: 42.76%, Test Loss: 2.0571, Test Acc: 60.85%
# Epoch 93/200 - Train Loss: 2.7885, Train Acc: 43.75%, Test Loss: 2.0411, Test Acc: 61.62%
# Epoch 94/200 - Train Loss: 2.7518, Train Acc: 44.69%, Test Loss: 2.0428, Test Acc: 61.42%
# Epoch 95/200 - Train Loss: 2.7612, Train Acc: 44.05%, Test Loss: 2.0110, Test Acc: 61.80%
# Epoch 96/200 - Train Loss: 2.8177, Train Acc: 42.83%, Test Loss: 2.0566, Test Acc: 60.77%
# Epoch 97/200 - Train Loss: 2.7509, Train Acc: 44.62%, Test Loss: 2.0381, Test Acc: 60.88%
# Epoch 98/200 - Train Loss: 2.8174, Train Acc: 43.19%, Test Loss: 1.9946, Test Acc: 62.07%
# Epoch 99/200 - Train Loss: 2.7056, Train Acc: 45.71%, Test Loss: 2.0114, Test Acc: 62.07%
# Epoch 100/200 - Train Loss: 2.6585, Train Acc: 46.94%, Test Loss: 1.9941, Test Acc: 63.03%
# Epoch 101/200 - Train Loss: 2.7075, Train Acc: 45.89%, Test Loss: 1.9989, Test Acc: 62.74%
# Epoch 102/200 - Train Loss: 2.7175, Train Acc: 45.68%, Test Loss: 1.9874, Test Acc: 63.07%
# Epoch 103/200 - Train Loss: 2.6597, Train Acc: 47.18%, Test Loss: 2.0202, Test Acc: 61.42%
# Epoch 104/200 - Train Loss: 2.6713, Train Acc: 46.67%, Test Loss: 1.9825, Test Acc: 62.67%
# Epoch 105/200 - Train Loss: 2.7237, Train Acc: 45.67%, Test Loss: 1.9726, Test Acc: 63.30%
# Epoch 106/200 - Train Loss: 2.6709, Train Acc: 46.99%, Test Loss: 1.9875, Test Acc: 63.35%
# Epoch 107/200 - Train Loss: 2.6646, Train Acc: 47.37%, Test Loss: 1.9869, Test Acc: 63.29%
# Epoch 108/200 - Train Loss: 2.6076, Train Acc: 48.69%, Test Loss: 1.9918, Test Acc: 62.83%
# Epoch 109/200 - Train Loss: 2.6213, Train Acc: 48.37%, Test Loss: 1.9908, Test Acc: 63.28%
# Epoch 110/200 - Train Loss: 2.5796, Train Acc: 49.32%, Test Loss: 2.0212, Test Acc: 62.49%
# Epoch 111/200 - Train Loss: 2.6075, Train Acc: 48.81%, Test Loss: 1.9834, Test Acc: 63.47%
# Epoch 112/200 - Train Loss: 2.6522, Train Acc: 47.62%, Test Loss: 1.9731, Test Acc: 62.80%
# Epoch 113/200 - Train Loss: 2.5816, Train Acc: 49.40%, Test Loss: 1.9802, Test Acc: 63.97%
# Epoch 114/200 - Train Loss: 2.6136, Train Acc: 49.01%, Test Loss: 1.9564, Test Acc: 63.91%
# Epoch 115/200 - Train Loss: 2.5288, Train Acc: 51.00%, Test Loss: 1.9753, Test Acc: 64.05%
# Epoch 116/200 - Train Loss: 2.5432, Train Acc: 50.75%, Test Loss: 1.9766, Test Acc: 63.95%
# Epoch 117/200 - Train Loss: 2.6415, Train Acc: 48.34%, Test Loss: 1.9741, Test Acc: 64.11%
# Epoch 118/200 - Train Loss: 2.6060, Train Acc: 49.45%, Test Loss: 1.9629, Test Acc: 63.91%
# Epoch 119/200 - Train Loss: 2.5414, Train Acc: 50.75%, Test Loss: 1.9627, Test Acc: 64.12%
# Epoch 120/200 - Train Loss: 2.6038, Train Acc: 49.48%, Test Loss: 1.9593, Test Acc: 63.80%
# Epoch 121/200 - Train Loss: 2.5713, Train Acc: 50.43%, Test Loss: 1.9308, Test Acc: 64.99%
# Epoch 122/200 - Train Loss: 2.5192, Train Acc: 51.85%, Test Loss: 1.9551, Test Acc: 64.42%
# Epoch 123/200 - Train Loss: 2.5542, Train Acc: 50.64%, Test Loss: 1.9904, Test Acc: 63.48%
# Epoch 124/200 - Train Loss: 2.5951, Train Acc: 49.88%, Test Loss: 1.9635, Test Acc: 63.78%
# Epoch 125/200 - Train Loss: 2.5091, Train Acc: 52.04%, Test Loss: 1.9342, Test Acc: 64.93%
# Epoch 126/200 - Train Loss: 2.4630, Train Acc: 53.03%, Test Loss: 1.9591, Test Acc: 64.71%
# Epoch 127/200 - Train Loss: 2.5816, Train Acc: 50.43%, Test Loss: 1.9506, Test Acc: 64.30%
# Epoch 128/200 - Train Loss: 2.4905, Train Acc: 52.42%, Test Loss: 1.9322, Test Acc: 65.34%
# Epoch 129/200 - Train Loss: 2.5041, Train Acc: 52.30%, Test Loss: 1.9229, Test Acc: 64.88%
# Epoch 130/200 - Train Loss: 2.4689, Train Acc: 53.21%, Test Loss: 1.9378, Test Acc: 64.93%
# Epoch 131/200 - Train Loss: 2.4696, Train Acc: 53.12%, Test Loss: 1.9547, Test Acc: 64.26%
# Epoch 132/200 - Train Loss: 2.4140, Train Acc: 54.68%, Test Loss: 1.9643, Test Acc: 63.91%
# Epoch 133/200 - Train Loss: 2.4827, Train Acc: 52.79%, Test Loss: 1.9440, Test Acc: 64.87%
# Epoch 134/200 - Train Loss: 2.4494, Train Acc: 53.80%, Test Loss: 1.9512, Test Acc: 65.11%
# Epoch 135/200 - Train Loss: 2.3923, Train Acc: 55.44%, Test Loss: 1.9414, Test Acc: 64.94%
# Epoch 136/200 - Train Loss: 2.4207, Train Acc: 54.56%, Test Loss: 1.9742, Test Acc: 63.66%
# Epoch 137/200 - Train Loss: 2.4088, Train Acc: 55.42%, Test Loss: 1.9479, Test Acc: 64.41%
# Epoch 138/200 - Train Loss: 2.3900, Train Acc: 55.42%, Test Loss: 1.9548, Test Acc: 64.08%
# Epoch 139/200 - Train Loss: 2.4363, Train Acc: 54.40%, Test Loss: 1.9537, Test Acc: 64.40%
# Epoch 140/200 - Train Loss: 2.3651, Train Acc: 56.51%, Test Loss: 1.9469, Test Acc: 65.09%
# Epoch 141/200 - Train Loss: 2.4351, Train Acc: 54.57%, Test Loss: 1.9331, Test Acc: 64.98%
# Epoch 142/200 - Train Loss: 2.3532, Train Acc: 56.28%, Test Loss: 1.9396, Test Acc: 64.47%
# Epoch 143/200 - Train Loss: 2.3727, Train Acc: 56.17%, Test Loss: 1.9418, Test Acc: 64.97%
# Epoch 144/200 - Train Loss: 2.4080, Train Acc: 55.54%, Test Loss: 1.9471, Test Acc: 64.70%
# Epoch 145/200 - Train Loss: 2.3507, Train Acc: 56.92%, Test Loss: 1.9329, Test Acc: 65.24%
# Epoch 146/200 - Train Loss: 2.3332, Train Acc: 57.26%, Test Loss: 1.9468, Test Acc: 65.55%
# Epoch 147/200 - Train Loss: 2.3858, Train Acc: 56.35%, Test Loss: 1.9284, Test Acc: 65.22%
# Epoch 148/200 - Train Loss: 2.3503, Train Acc: 57.04%, Test Loss: 1.9177, Test Acc: 65.91%
# Epoch 149/200 - Train Loss: 2.3076, Train Acc: 58.35%, Test Loss: 1.9554, Test Acc: 64.79%
# Epoch 150/200 - Train Loss: 2.3094, Train Acc: 58.41%, Test Loss: 1.9394, Test Acc: 65.65%
# Epoch 151/200 - Train Loss: 2.2814, Train Acc: 58.82%, Test Loss: 1.9339, Test Acc: 65.36%
# Epoch 152/200 - Train Loss: 2.3738, Train Acc: 56.63%, Test Loss: 1.9411, Test Acc: 65.78%
# Epoch 153/200 - Train Loss: 2.3725, Train Acc: 56.59%, Test Loss: 1.9138, Test Acc: 65.72%
# Epoch 154/200 - Train Loss: 2.3844, Train Acc: 56.30%, Test Loss: 1.9291, Test Acc: 65.65%
# Epoch 155/200 - Train Loss: 2.3595, Train Acc: 56.89%, Test Loss: 1.9467, Test Acc: 65.22%
# Epoch 156/200 - Train Loss: 2.3200, Train Acc: 57.92%, Test Loss: 1.9280, Test Acc: 65.82%
# Epoch 157/200 - Train Loss: 2.4126, Train Acc: 55.44%, Test Loss: 1.9031, Test Acc: 66.12%
# Epoch 158/200 - Train Loss: 2.3506, Train Acc: 57.24%, Test Loss: 1.9338, Test Acc: 66.02%
# Epoch 159/200 - Train Loss: 2.2820, Train Acc: 58.97%, Test Loss: 1.9455, Test Acc: 65.13%
# Epoch 160/200 - Train Loss: 2.3495, Train Acc: 57.30%, Test Loss: 1.9371, Test Acc: 65.47%
# Epoch 161/200 - Train Loss: 2.3423, Train Acc: 57.50%, Test Loss: 1.9248, Test Acc: 65.63%
# Epoch 162/200 - Train Loss: 2.3184, Train Acc: 58.51%, Test Loss: 1.9089, Test Acc: 66.32%
# Epoch 163/200 - Train Loss: 2.2790, Train Acc: 59.50%, Test Loss: 1.9160, Test Acc: 66.19%
# Epoch 164/200 - Train Loss: 2.2899, Train Acc: 59.07%, Test Loss: 1.9234, Test Acc: 65.83%
# Epoch 165/200 - Train Loss: 2.3543, Train Acc: 57.68%, Test Loss: 1.9190, Test Acc: 66.16%
# Epoch 166/200 - Train Loss: 2.2340, Train Acc: 60.56%, Test Loss: 1.9059, Test Acc: 66.61%
# Epoch 167/200 - Train Loss: 2.2464, Train Acc: 60.44%, Test Loss: 1.9298, Test Acc: 65.42%
# Epoch 168/200 - Train Loss: 2.3051, Train Acc: 58.58%, Test Loss: 1.8982, Test Acc: 66.44%
# Epoch 169/200 - Train Loss: 2.2683, Train Acc: 59.79%, Test Loss: 1.9023, Test Acc: 66.64%
# Epoch 170/200 - Train Loss: 2.2268, Train Acc: 60.98%, Test Loss: 1.9149, Test Acc: 65.66%
# Epoch 171/200 - Train Loss: 2.2819, Train Acc: 59.30%, Test Loss: 1.9134, Test Acc: 66.49%
# Epoch 172/200 - Train Loss: 2.2060, Train Acc: 61.41%, Test Loss: 1.9160, Test Acc: 66.28%
# Epoch 173/200 - Train Loss: 2.2762, Train Acc: 59.81%, Test Loss: 1.9145, Test Acc: 66.22%
# Epoch 174/200 - Train Loss: 2.3560, Train Acc: 57.32%, Test Loss: 1.9254, Test Acc: 66.07%
# Epoch 175/200 - Train Loss: 2.2984, Train Acc: 59.15%, Test Loss: 1.9249, Test Acc: 65.67%
# Epoch 176/200 - Train Loss: 2.2642, Train Acc: 60.01%, Test Loss: 1.9032, Test Acc: 66.82%
# Epoch 177/200 - Train Loss: 2.3065, Train Acc: 58.87%, Test Loss: 1.9064, Test Acc: 66.38%
# Epoch 178/200 - Train Loss: 2.1913, Train Acc: 61.99%, Test Loss: 1.9140, Test Acc: 66.40%
# Epoch 179/200 - Train Loss: 2.2608, Train Acc: 60.18%, Test Loss: 1.9098, Test Acc: 66.56%
# Epoch 180/200 - Train Loss: 2.1872, Train Acc: 62.24%, Test Loss: 1.9129, Test Acc: 66.50%
# Epoch 181/200 - Train Loss: 2.3301, Train Acc: 58.48%, Test Loss: 1.9012, Test Acc: 66.84%
# Epoch 182/200 - Train Loss: 2.3196, Train Acc: 58.72%, Test Loss: 1.9004, Test Acc: 66.50%
# Epoch 183/200 - Train Loss: 2.3610, Train Acc: 57.77%, Test Loss: 1.9115, Test Acc: 66.02%
# Epoch 184/200 - Train Loss: 2.1687, Train Acc: 62.44%, Test Loss: 1.9127, Test Acc: 66.76%
# Epoch 185/200 - Train Loss: 2.3035, Train Acc: 59.22%, Test Loss: 1.9179, Test Acc: 66.23%
# Epoch 186/200 - Train Loss: 2.2596, Train Acc: 60.25%, Test Loss: 1.9009, Test Acc: 66.49%
# Epoch 187/200 - Train Loss: 2.1624, Train Acc: 62.75%, Test Loss: 1.9173, Test Acc: 66.23%
# Epoch 188/200 - Train Loss: 2.2612, Train Acc: 59.87%, Test Loss: 1.9077, Test Acc: 66.80%
# Epoch 189/200 - Train Loss: 2.2750, Train Acc: 59.95%, Test Loss: 1.9048, Test Acc: 66.32%
# Epoch 190/200 - Train Loss: 2.1822, Train Acc: 62.25%, Test Loss: 1.9100, Test Acc: 66.22%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-436865fde0dc> in <cell line: 245>()
#     244
#     245 if __name__ == '__main__':
# --> 246     main()
#
# <ipython-input-20-436865fde0dc> in main()
#     202                 loss = criterion(outputs, targets)
#     203
# --> 204                 test_loss += loss.item()
#     205                 _, predicted = outputs.max(1)
#     206                 total += targets.size(0)
#
# KeyboardInterrupt:
